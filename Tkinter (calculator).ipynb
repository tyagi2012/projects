# %%
from tkinter import *
def clear():
    el.delete(0,"end")

abc=Tk()
abc.state("zoomed")
abc.title("Calculator")
abc.configure(bg="powder blue")


e1=Entry(abc,font=(' ',40,'bold'),bd=5)
e1.place(relx=0,rely=0.05)


b1=Button(abc,text=" / ",font=(' ',24,'bold'),bd=5)
b1.place(relx=0.30,rely=0.2)

b2=Button(abc,text=" - ",font=(' ',24,'bold'),bd=5)
b2.place(relx=0.30,rely=0.8)

b3=Button(abc,text=" x ",font=(' ',24,'bold'),bd=5)
b3.place(relx=0.30,rely=0.4)

b4=Button(abc,text=" + ",font=(' ',24,'bold'),bd=5)
b4.place(relx=0.30,rely=0.6)

b5=Button(abc,text=" 7 ",font=(' ',24,'bold'),bd=5)
b5.place(relx=0.00,rely=0.2)

b6=Button(abc,text=" 8 ",font=(' ',24,'bold'),bd=5)
b6.place(relx=0.10,rely=0.2)

b7=Button(abc,text=" 9 ",font=(' ',24,'bold'),bd=5)
b7.place(relx=0.20,rely=0.2)

b8=Button(abc,text=" 4 ",font=(' ',24,'bold'),bd=5)
b8.place(relx=0.00,rely=0.4)

b9=Button(abc,text=" 5 ",font=(' ',24,'bold'),bd=5)
b9.place(relx=0.10,rely=0.4)

b10=Button(abc,text=" 6 ",font=(' ',24,'bold'),bd=5)
b10.place(relx=0.20,rely=0.4)

b11=Button(abc,text=" 1 ",font=(' ',24,'bold'),bd=5)
b11.place(relx=0.00,rely=0.6)

b12=Button(abc,text=" 2 ",font=(' ',24,'bold'),bd=5)
b12.place(relx=0.10,rely=0.6)

b12=Button(abc,text=" 3 ",font=(' ',24,'bold'),bd=5)
b12.place(relx=0.20,rely=0.6)

b13=Button(abc,text=" = ",font=(' ',24,'bold'),bd=5)
b13.place(relx=0.20,rely=0.8)



b10=Button(abc,text=" . ",font=(' ',24,'bold'),bd=5)
b10.place(relx=0.10,rely=0.8)

b10=Button(abc,text=" 0 ",font=(' ',24,'bold'),bd=5)
b10.place(relx=0.00,rely=0.8)
